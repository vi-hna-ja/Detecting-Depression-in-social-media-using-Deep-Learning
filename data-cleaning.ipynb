# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
path = '/content/gdrive/MyDrive/Detecting depression/'
print(os.listdir(path))
# Out:
# ['depression', 'lonely', 'hopeless', 'suicide', 'antidepressant', 'depressed', 'antidepressants']

# %%
datasets = list(os.listdir(path))
datasets
# Out:
# ['depression',
#  'lonely',
#  'hopeless',
#  'suicide',
#  'antidepressant',
#  'depressed',
#  'antidepressants']

# %%
import pandas as pd

dataframes = []
for ds in datasets:
  new_path = path + ds + '/tweets.csv'
  df = pd.read_csv(new_path)
  dataframes.append(df)

# %%
for i in range(len(dataframes)):
  print('---------------------------------------------------------------------')
  print('{} head'.format(datasets[i].capitalize()))
  print(dataframes[i].head(3))
# Out:
# ---------------------------------------------------------------------
# Depression head
#                     id      conversation_id  ...  near geo
# 0  1151347096966041603  1151347096966041603  ...   NaN NaN
# 1  1151347069627576320  1150980638247231489  ...   NaN NaN
# 2  1151347066255396865  1151347066255396865  ...   NaN NaN
#
# [3 rows x 26 columns]
# ---------------------------------------------------------------------
# Lonely head
#                     id      conversation_id  ...  near geo
# 0  1152982582843326466  1152982582843326466  ...   NaN NaN
# 1  1152982578741284865  1152916420587675648  ...   NaN NaN
# 2  1152982577181024259  1152976191781048322  ...   NaN NaN
#
# [3 rows x 26 columns]
# ---------------------------------------------------------------------
# Hopeless head
#                     id      conversation_id  ...  near geo
# 0  1151526536471728134  1151526536471728134  ...   NaN NaN
# 1  1151526442922139649  1151524002457882624  ...   NaN NaN
# ...

# %%
df1_cols = dataframes[0].columns
for i in range(1, len(dataframes)):
  print(df1_cols == dataframes[i].columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]

# %%
columns_to_drop = ['date', 'timezone', 'username', 'name', 'conversation_id', 'created_at', 'user_id', 'place', 'likes_count', 'link', 'retweet', 'quote_url', 'video', 'user_rt_id', 'near', 'geo', 'mentions', 'urls', 'photos', 'replies_count', 'retweets_count']

# %%
for dataframe in dataframes:
  dataframe = dataframe.drop(columns_to_drop, axis=1, inplace=True)

# %%
for i in range(len(dataframes)):
  print('---------------------------------------------------------------------')
  print('{} head'.format(datasets[i].capitalize()))
  print(dataframes[i].head(3))
# Out:
# ---------------------------------------------------------------------
# Depression head
#                     id  ... cashtags
# 0  1151347096966041603  ...       []
# 1  1151347069627576320  ...       []
# 2  1151347066255396865  ...       []
#
# [3 rows x 5 columns]
# ---------------------------------------------------------------------
# Lonely head
#                     id      time  ... hashtags cashtags
# 0  1152982582843326466  09:44:03  ...       []       []
# 1  1152982578741284865  09:44:02  ...       []       []
# 2  1152982577181024259  09:44:02  ...       []       []
#
# [3 rows x 5 columns]
# ---------------------------------------------------------------------
# Hopeless head
#                     id      time  ... hashtags cashtags
# 0  1151526536471728134  09:18:15  ...       []       []
# 1  1151526442922139649  09:17:52  ...       []       []
# 2  1151526396210110464  09:17:41  ...       []       []
#
# [3 rows x 5 columns]
# ...

# %%
datasets
# Out:
# ['depression',
#  'lonely',
#  'hopeless',
#  'suicide',
#  'antidepressant',
#  'depressed',
#  'antidepressants']

# %%
print("Depression Tweets head")
dataframes[0].head()
# Out:
# Depression Tweets head
#                     id  ... cashtags
# 0  1151347096966041603  ...       []
# 1  1151347069627576320  ...       []
# 2  1151347066255396865  ...       []
# 3  1151347022789611520  ...       []
# 4  1151347006406893568  ...       []
#
# [5 rows x 5 columns]

# %%
print("Lonely Tweets head")
dataframes[1].head()
# Out:
# Lonely Tweets head
#                     id      time  ...         hashtags cashtags
# 0  1152982582843326466  09:44:03  ...               []       []
# 1  1152982578741284865  09:44:02  ...               []       []
# 2  1152982577181024259  09:44:02  ...               []       []
# 3  1152982576153239552  09:44:02  ...  ['#nowplaying']       []
# 4  1152982566263296000  09:43:59  ...               []       []
#
# [5 rows x 5 columns]

# %%
print("Hopeless Tweets head")
dataframes[3].head()
# Out:
# Hopeless Tweets head
#                     id      time  ...              hashtags cashtags
# 0  1152996044604682241  10:37:33  ...                    []       []
# 1  1152995993148899329  10:37:21  ...                    []       []
# 2  1152995985053900800  10:37:19  ...                    []       []
# 3  1152995984642887683  10:37:19  ...                    []       []
# 4  1152995955559620608  10:37:12  ...  ['#sam', '#suicide']       []
#
# [5 rows x 5 columns]

# %%
print("Suicide Tweets head")
dataframes[4].head()
# Out:
# Suicide Tweets head
#                     id  ... cashtags
# 0  1152991919137538048  ...       []
# 1  1152991631722913793  ...       []
# 2  1152991531789406209  ...       []
# 3  1152991116733628416  ...       []
# 4  1152990783420751872  ...       []
#
# [5 rows x 5 columns]

# %%
print("Anti-Depressant Tweets head")
dataframes[5].head()
# Out:
# Anti-Depressant Tweets head
#                     id      time  ... hashtags cashtags
# 0  1151315262748205057  19:18:43  ...       []       []
# 1  1151315254615400448  19:18:41  ...       []       []
# 2  1151315222692429825  19:18:34  ...       []       []
# 3  1151315218011549696  19:18:33  ...       []       []
# 4  1151315209413386240  19:18:30  ...       []       []
#
# [5 rows x 5 columns]

# %%
print("Depressed Tweets head")
dataframes[2].head()
# Out:
# Depressed Tweets head
#                     id      time  ... hashtags cashtags
# 0  1151526536471728134  09:18:15  ...       []       []
# 1  1151526442922139649  09:17:52  ...       []       []
# 2  1151526396210110464  09:17:41  ...       []       []
# 3  1151526283890683904  09:17:15  ...       []       []
# 4  1151526267738628097  09:17:11  ...       []       []
#
# [5 rows x 5 columns]

# %%
print("Anti-Depressants Tweets head")
dataframes[6].head()
# Out:
# Anti-Depressants Tweets head
#                     id      time  ... hashtags cashtags
# 0  1152995178359218176  10:34:06  ...       []       []
# 1  1152994945537576960  10:33:11  ...       []       []
# 2  1152994834359209985  10:32:44  ...       []       []
# 3  1152994452606033920  10:31:13  ...       []       []
# 4  1152994432188370949  10:31:08  ...       []       []
#
# [5 rows x 5 columns]

# %%
df_row_reindex = pd.concat(dataframes, ignore_index=True)
df_row_reindex
# Out:
#                          id  ... cashtags
# 0       1151347096966041603  ...       []
# 1       1151347069627576320  ...       []
# 2       1151347066255396865  ...       []
# 3       1151347022789611520  ...       []
# 4       1151347006406893568  ...       []
# ...                     ...  ...      ...
# 135469  1152369599368892416  ...       []
# 135470  1152369434520104962  ...       []
# 135471  1152368694263275520  ...       []
# 135472  1152368663833354241  ...       []
# 135473  1152367558420340736  ...       []
#
# [135474 rows x 5 columns]

# %%
df = df_row_reindex
print(df.shape)
depressive_tweets = df.drop_duplicates()
print(depressive_tweets.shape)
# Out:
# (135474, 5)
# (134085, 5)

# %%
depressive_tweets.to_csv(r'/content/gdrive/MyDrive/depressive_tweets_final.csv')

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline
#%config InlineBackend.figure_format = 'retina'

# %%
# !pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 7.6MB/s
# ...

# %%
import nltk
nltk.download(['punkt','stopwords'])
from nltk.corpus import stopwords
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords = stopwords.words('english')
analyzer = SentimentIntensityAnalyzer()

# %%
path = '/content/gdrive/MyDrive/'
df2 = pd.read_csv(path + 'depressive_tweets_final.csv', lineterminator='\n')

# %%
df2.head()
# Out:
#    Unnamed: 0  ...  cashtags
# 0           0  ...        []
# 1           1  ...        []
# 2           2  ...        []
# 3           3  ...        []
# 4           4  ...        []
#
# [5 rows x 6 columns]

# %%
df2.isnull().any().sum()
# Out:
# 0

# %%
df2.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134085 entries, 0 to 134084
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  134085 non-null  int64
#  1   id          134085 non-null  int64
#  2   time        134085 non-null  object
#  3   tweet       134085 non-null  object
#  4   hashtags    134085 non-null  object
#  5   cashtags    134085 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 6.1+ MB

# %%
df_new = df2[df2['tweet'].notnull()]

# %%
df_new.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134085 entries, 0 to 134084
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  134085 non-null  int64
#  1   id          134085 non-null  int64
#  2   time        134085 non-null  object
#  3   tweet       134085 non-null  object
#  4   hashtags    134085 non-null  object
#  5   cashtags    134085 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 7.2+ MB

# %%
df_new.isnull().any().sum()
# Out:
# 0

# %%
df_new['cleaned_tweet'] = df.tweet.apply(lambda x : ' '.join(list(i for i in x.split() if i not in stopwords)))

# %%
df_new.tweet.head(10)
# Out:
# 0    Wow, my dad yday: “you don’t take those stupid...
# 1    what part of this was really harmfult of a lot...
# 2    one of the ways I got through my #depression i...
# 3    see i wanna do one of them but they all say th...
# 4    IS IT clinical depression or is it the palpabl...
# 5    My new mantra for dealing with my anxiety/depr...
# 6    Can I get a woot woot for 3 months depression ...
# 7    Hope it's working for you.  I was on sertralin...
# 8    When my depression and anxiety strike at the s...
# 9    I want to leave, but I'm still waiting for you...
# Name: tweet, dtype: object

# %%
df_new['vader_score'] = df_new.cleaned_tweet.apply(lambda x : analyzer.polarity_scores(x)['compound'])

# %%
df_new.head(10)
# Out:
#    Unnamed: 0  ...  vader_score
# 0           0  ...      -0.4122
# 1           1  ...      -0.8074
# 2           2  ...       0.3382
# 3           3  ...      -0.4588
# 4           4  ...      -0.8316
# 5           5  ...       0.0516
# 6           6  ...       0.6369
# 7           7  ...      -0.3612
# 8           8  ...      -0.7096
# 9           9  ...      -0.9781
#
# [10 rows x 8 columns]

# %%
pos_cnt = len(df_new[df_new.vader_score >= 0.05])
neg_cnt = len(df_new[df_new.vader_score < -0.05])

# %%
print(pos_cnt, neg_cnt)
# Out:
# 29188 72790

# %%
df_new['vader_sentiment_label']= df_new['vader_score'].map(lambda x:int(1) if x>=0.05 else int(0))

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                   id  ... vader_score vader_sentiment_label
# 0           0  1151347096966041603  ...     -0.4122                     0
# 1           1  1151347069627576320  ...     -0.8074                     0
# 2           2  1151347066255396865  ...      0.3382                     1
# 3           3  1151347022789611520  ...     -0.4588                     0
# 4           4  1151347006406893568  ...     -0.8316                     0
# 5           5  1151346982239297540  ...      0.0516                     1
# 6           6  1151346962760904705  ...      0.6369                     1
# 7           7  1151346946675789830  ...     -0.3612                     0
# 8           8  1151346882561503233  ...     -0.7096                     0
# 9           9  1151346874030235654  ...     -0.9781                     0
#
# [10 rows x 9 columns]

# %%
df_new.drop(['Unnamed: 0', 'id', 'tweet', 'time'], axis=1, inplace=True)

# %%
df_new.head(10)
# Out:
#                                             hashtags  ... vader_sentiment_label
# 0                                                 []  ...                     0
# 1                                                 []  ...                     0
# 2  ['#depression', '#uncoveringthenewu', '#change...  ...                     1
# 3                                                 []  ...                     0
# 4                                                 []  ...                     0
# 5                                                 []  ...                     1
# 6                                                 []  ...                     1
# 7                                                 []  ...                     0
# 8                                                 []  ...                     0
# 9                                                 []  ...                     0
#
# [10 rows x 5 columns]

# %%
df_new = df_new[['cleaned_tweet', 'vader_score', 'vader_sentiment_label']]

# %%
df_new.head(10)
# Out:
#                                        cleaned_tweet  ...  vader_sentiment_label
# 0  Wow, dad yday: “you don’t take stupid depressi...  ...                      0
# 1  part really harmfult lot people went every gui...  ...                      0
# 2  one ways I got #depression learning dance rain...  ...                      1
# 3  see wanna one say PTSD, depression, and/or anx...  ...                      0
# 4  IS IT clinical depression palpable hopelessnes...  ...                      0
# 5  My new mantra dealing anxiety/depression overa...  ...                      1
# 6  Can I get woot woot 3 months depression medica...  ...                      1
# 7  Hope working you. I sertraline year helped dep...  ...                      0
# 8  When depression anxiety strike time I can’t an...  ...                      0
# 9  I want leave, I'm still waiting legalize Assis...  ...                      0
#
# [10 rows x 3 columns]

# %%
pos_cnt = len(df_new[df_new['vader_score'] >=0.05])
neg_cnt = len(df_new[df_new['vader_score']<=-0.05])
neut_cnt = len(df_new[(df_new['vader_score'] >-0.05) & (df_new['vader_score']<0.05)])

# %%
print("Positive tweets: {}   Negitive tweets: {}     Neutral tweets: {}".format(pos_cnt, neg_cnt, neut_cnt))
# Out:
# Positive tweets: 29188   Negitive tweets: 72790     Neutral tweets: 32107

# %%
df_new.to_csv(r'/content/gdrive/MyDrive/vader_processed_final.csv')

# %%
import itertools
import collections
import seaborn as sns
import nltk
import re
from nltk import bigrams
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
df_new['text'] = df_new['cleaned_tweet']

all_tweets_no_urls = [remove_url(tweet) for tweet in df_new['text']]
all_tweets_no_urls[:5]
# Out:
# ['Wow dad yday you dont take stupid depression drugs anymore though you Because theyre absolute worst thing and never need them Aint great family supportive My moms sisters stance similar btw',
#  'part really harmfult lot people went every guideline understand 13rw horror show supposed insight depression mental illness overall helpful public narrative topic',
#  'one ways I got depression learning dance rain It source strength stronger circumstances UncoveringthenewU ChangeYourMindChangeYourCircumstances pictwittercom3vxKuQ0DvD',
#  'see wanna one say PTSD depression andor anxiety play LIKEE',
#  'IS IT clinical depression palpable hopelessness generation']

# %%
words_in_tweet = [tweet.lower().split() for tweet in all_tweets_no_urls]

# %%
# List of all words across tweets
all_words_no_urls = list(itertools.chain(*words_in_tweet))

# Create counter
counts_no_urls = collections.Counter(all_words_no_urls)

counts_no_urls.most_common(15)
# Out:
# [('i', 42687),
#  ('lonely', 27794),
#  ('depression', 25132),
#  ('suicide', 20315),
#  ('im', 18232),
#  ('depressed', 13344),
#  ('like', 9672),
#  ('people', 7589),
#  ('you', 6432),
#  ('the', 6422),
#  ('feel', 6371),
#  ('its', 6098),
#  ('get', 5923),
#  ('hopeless', 5637),
#  ('it', 5582)]

# %%
clean_tweets_no_urls = pd.DataFrame(counts_no_urls.most_common(15), columns=['words', 'count'])
clean_tweets_no_urls.head()
# Out:
#         words  count
# 0           i  42687
# 1      lonely  27794
# 2  depression  25132
# 3     suicide  20315
# 4          im  18232

# %%
stop_words = set(stopwords)
list(stop_words)[0:10]
# Out:
# ['who',
#  'than',
#  'under',
#  'is',
#  'too',
#  'weren',
#  'wouldn',
#  'don',
#  'both',
#  "hadn't"]

# %%
words_in_tweet[0]
# Out:
# ['wow',
#  'dad',
#  'yday',
#  'you',
#  'dont',
#  'take',
#  'stupid',
#  'depression',
#  'drugs',
#  'anymore',
#  'though',
#  'you',
#  'because',
#  'theyre',
#  'absolute',
#  'worst',
#  'thing',
#  'and',
#  'never',
#  'need',
#  'them',
#  'aint',
#  'great',
#  'family',
#  'supportive',
#  'my',
#  'moms',
#  'sisters',
#  'stance',
#  'similar',
#  'btw']

# %%
# Remove stop words from each tweet list of words
tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_in_tweet]

tweets_nsw[0]
# Out:
# ['wow',
#  'dad',
#  'yday',
#  'dont',
#  'take',
#  'stupid',
#  'depression',
#  'drugs',
#  'anymore',
#  'though',
#  'theyre',
#  'absolute',
#  'worst',
#  'thing',
#  'never',
#  'need',
#  'aint',
#  'great',
#  'family',
#  'supportive',
#  'moms',
#  'sisters',
#  'stance',
#  'similar',
#  'btw']

# %%
all_words_nsw = list(itertools.chain(*tweets_nsw))
counts_nsw = collections.Counter(all_words_nsw)
counts_nsw.most_common(15)
# Out:
# [('lonely', 27794),
#  ('depression', 25132),
#  ('suicide', 20315),
#  ('im', 18232),
#  ('depressed', 13344),
#  ('like', 9672),
#  ('people', 7589),
#  ('feel', 6371),
#  ('get', 5923),
#  ('hopeless', 5637),
#  ('one', 5501),
#  ('know', 5097),
#  ('dont', 5030),
#  ('time', 4806),
#  ('de', 4640)]

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in tweets_nsw_nc]
# View bigrams for the first tweet
terms_bigram[0]
